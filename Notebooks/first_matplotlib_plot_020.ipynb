# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig.savefig('figure.png')

# %%
plt.figure()

plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))

plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

# %%
fig, ax = plt.subplots(2)
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %%
fig, ax = plt.subplots(2)
ax[0].plot(x, np.sin(x), color='green', linestyle='dashed')
ax[1].plot(x, np.cos(x), color="#20f000", linestyle=':')

# %%
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), label="Sin Wave", color='green')
plt.plot(x, np.cos(x), label="Cos Wave")

plt.xlim(-2, 12)
plt.ylim(-1.25, 1.5)

plt.title("My First Plot")
plt.xlabel("X")
plt.ylabel("Y")

plt.legend()

# %%
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), 'o')

# %%
y = np.sin(x)
plt.plot(x, y, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2)
# Out:
# (-1.2, 1.2)

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
           cmap='spring')
plt.colorbar()

# %%
data = np.random.randn(1000)
plt.hist(data, bins=6, density=True)
# Out:
# (array([0.01014782, 0.10824342, 0.32642156, 0.29682375, 0.09133038,
#         0.01268478]),
#  array([-3.47213114, -2.28961121, -1.10709128,  0.07542865,  1.25794857,
#          2.4404685 ,  3.62298843]),
#  <BarContainer object of 6 artists>)

# %%
np.random.seed(42)

x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))

plt.bar(x, y, width=1, edgecolor='white', linewidth=0.7)
# Out:
# <BarContainer object of 8 artists>
